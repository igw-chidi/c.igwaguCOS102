# %%
# Izifin Technology Annual Tax Revenue 


experience = input("Enter your years of experience")
age = input("Enter your age")

exp = int(experience)
age = int(age)

if age >= 55 and exp > 25:
    print("Your Annual Tax Revenue is 5 million naira")

elif age >= 45 and exp > 20: 
     print("Your Annual Tax Revenue is 4.48 million naira")

elif age >= 35 and exp > 10 :
    print("Your Annual Tax Revenue is 1.5 million naira")

else:
    print("Your Annual Tax Revenue is 1.5 million naira")
# Out:
# Enter your years of experience 34
# Enter your age 34
#   Cell In[17], line 22
#     return
#     ^
# SyntaxError: 'return' outside function
