# %% [markdown]
# ![Screenshot 2026-03-11 161337.png](attachment:29a0d053-6290-4f04-a6e1-f7d8f7e2b933.png)

# %%
# Get input from user
item_name = input("Enter item name: ")
quantity_bought = int(input("Enter quantity bought: "))
price_of_item = float(input("Enter price per item: "))

# Calculate total
total_amount = quantity_bought * price_of_item

# Display result
print(f"Total amount: ${total_amount:.2f}")

# Get payment method
payment_method = input("Enter payment method: ")
print(f"Payment of ${total_amount:.2f} will be processed via {payment_method}")
