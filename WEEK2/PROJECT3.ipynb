# %%
import pandas as pd 
# To display Names,Age,Height,Score
print("This is the Name,Age,Height and Score table for girls")
data = {
    "Name": ["Evelyn","Jessica","Somto","Edith","Madonna","Liza","Waje","Tola","Aisha","Latifa"],
    "Age": [17,16,17,18,16,16,17,20,19,17],
    "Height": [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5],
    "Scores": [80,85,70,60,76,66,87,95,50,49],
}
df = pd.DataFrame(data)
print(df)

print("This is the Name,Age,Height and Score table for boys")
data = {
    "Name": ["Chinedu","Liam","Wale","Gbenga","Abiola","Kola","Kunle","George","Thomas","Wesley"],
    "Age": [19,16,18,17,20,19,16,18,17,19],
    "Height": [5.7,5.9,5.8,6.1,5.9,5.5,6.1,5.4,5.8,5.7],
    "Scores": [74,87,75,60,76,66,87,95,50,49],
}
df = pd.DataFrame(data)
print(df)
# Out:
# This is the Name,Age,Height and Score table for girls
#       Name  Age  Height  Scores
# 0   Evelyn   17     5.5      80
# 1  Jessica   16     6.0      85
# 2    Somto   17     5.4      70
# 3    Edith   18     5.9      60
# 4  Madonna   16     5.6      76
# 5     Liza   16     5.5      66
# 6     Waje   17     6.1      87
# 7     Tola   20     6.0      95
# 8    Aisha   19     5.7      50
# 9   Latifa   17     5.5      49
